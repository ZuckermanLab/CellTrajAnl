# %% [markdown]
# ## Predict Cell-cycle Information from Morphodynamic features

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import numpy as np
import pandas as pd
import sys, os, time, math
import h5py 
sys.path.append('/home/groups/ZuckermanLab/jalim/instalLocal/celltraj/celltraj')
import jcTrajectory_CP as cellTraj
import pickle, subprocess
import umap, scipy, json 
from csaps import csaps
import string, ast 
from joblib import dump, load
from datetime import date
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# 2024-09-26 12:24:08.261609: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-26 12:24:08.291383: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-26 12:24:08.300365: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-26 12:24:08.324235: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-26 12:24:23.727159: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from sklearn.datasets import make_classification, make_regression
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix,\
precision_score, f1_score, recall_score, ConfusionMatrixDisplay
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.utils.class_weight import compute_class_weight
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestRegressor

# %%
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Reshape, Dense, Input, Dropout, LeakyReLU, BatchNormalization
from keras.optimizers import Adam, SGD
from keras.regularizers import l2, l1
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
from imblearn.over_sampling import RandomOverSampler, SMOTE, KMeansSMOTE, ADASYN

# %%
trajl = 1
today = date.today()
date2day = today.strftime("%b%d-%Y")
sysName = 'LI204601_P'
figid = f"{sysName}_{date2day}"

# %%
fovs = ['A2_1', 'A2_2', 'A2_3', 'B2_1', 'B2_3', 'B2_4']
nfovs = len(fovs)
pathSet = '/home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/segsCellPose/bayesianTrackTest/'
modelList = [None]*(nfovs)
modelList_conditions = np.zeros(nfovs).astype(int)

# %%
for i in range(nfovs):
    modelList_conditions[i] = i
    modelList[i] = f"{pathSet}{sysName}_{fovs[i]}"
    #print("Model Info: ",modelList[i])

nmodels = len(modelList)
modelSet = [None]*nmodels
indgood_models = np.array([]).astype(int)

# %%
for i in range(nmodels):
    try:
        objFile = modelList[i]+'.obj'
        objFileHandler = open(objFile,'rb')
        modelSet[i] = pickle.load(objFileHandler)
        print(f"loaded {objFile} with {modelSet[i].cells_indSet.size} cells")
        objFileHandler.close()
        test = len(modelSet[i].linSet)
        indgood_models = np.append(indgood_models, i)
    except:
        print("ERROR in reading *.obj files")
        sys.exit(0)
# Out:
# loaded /home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/segsCellPose/bayesianTrackTest/LI204601_P_A2_1.obj with 51054 cells
# loaded /home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/segsCellPose/bayesianTrackTest/LI204601_P_A2_2.obj with 97764 cells
# loaded /home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/segsCellPose/bayesianTrackTest/LI204601_P_A2_3.obj with 58579 cells
# loaded /home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/segsCellPose/bayesianTrackTest/LI204601_P_B2_1.obj with 67836 cells
# loaded /home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/segsCellPose/bayesianTrackTest/LI204601_P_B2_3.obj with 57884 cells
# loaded /home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/segsCellPose/bayesianTrackTest/LI204601_P_B2_4.obj with 46096 cells

# %%
n_frames = 193 # Total number of frames (image snapshots) in one condition per FOVs
cellnumber_stdSet = np.ones(nmodels)*np.inf
# range of frame indices where cell numbers are higher: ~70-98%
sframe = 70.*n_frames/100.; sframe = math.ceil(sframe)
eframe = 98.5*n_frames/100.; eframe = math.ceil(eframe)
cellnumber_frames = np.arange(sframe, eframe).astype(int)
cellnumber_std_cut = .50 # This was set to 0.10 by Jeremy 
frames = np.arange(n_frames)
# Abscissas at which smoothing will be done using CSAPS package
abSmooth = np.linspace(frames[0], frames[-1], 10000)

# %%
for i in indgood_models:
    ncells = np.zeros(n_frames)
    ncells_smooth = np.zeros_like(ncells)
    for iS in range(n_frames):
        ncells[iS] = np.sum(modelSet[i].cells_frameSet == iS)
    # Cubic Spline Approximation (CSAPS) to smoothen the data
    splfov = csaps(frames, ncells/ncells[0], abSmooth, smooth = 0.98) # Scaled by ncells[0] to avoid large numbers
    ncells_smooth = splfov*ncells[0] # smoothened cell numbers reverse scaled back to original
    cellnumber_std = np.std(ncells[cellnumber_frames] - ncells_smooth[cellnumber_frames])/np.mean(ncells[cellnumber_frames])
    cellnumber_stdSet[i] = cellnumber_std # Standard Deviation in Cell Numbers

# %%
indhigh_std = np.where(cellnumber_stdSet > cellnumber_std_cut)[0]
indgood_models = np.setdiff1d(indgood_models, indhigh_std)
for i in indgood_models:
    modelSet[i].Xf[np.isnan(modelSet[i].Xf)] = 0.0

# %%
n_COMfeatures = 3
Xf_com0 = np.zeros((0, n_COMfeatures))
for i in indgood_models:
    Xf_com0 = np.append(Xf_com0,modelSet[i].Xf_com, axis = 0)

av_dx = np.nanmean(Xf_com0[:, 0])
std_dx = np.nanstd(Xf_com0[:, 0])
for i in indgood_models:
    modelSet[i].Xf_com[:, 0] = (modelSet[i].Xf_com[:, 0] - av_dx)/std_dx

# %%
wctm = cellTraj.Trajectory() # import Trajectory object 
# Cell features: Zernike (49), Haralick (13), Shape (15), Boundary (15) --> total 92
n_features = modelSet[indgood_models[0]].Xf.shape[1]
Xf = np.zeros((0, n_features))
indtreatment = np.array([])
indcellSet = np.array([])

for i in indgood_models:
    Xf = np.append(Xf, modelSet[i].Xf, axis = 0)
    # Indices for each model for later access using them
    indtreatment = np.append(indtreatment, i*np.ones(modelSet[i].Xf.shape[0])) 
    indcellSet = np.append(indcellSet, modelSet[i].cells_indSet)

indtreatment = indtreatment.astype(int)
indcellSet = indcellSet.astype(int)

# %%
for i in indgood_models:
    indsf = np.where(indtreatment == i)[0]
    modelSet[i].Xf = Xf[indsf, :]

# %%
self = wctm
all_trajSet = [None]*nmodels
for i in indgood_models:
    print(f"Get single-cell trajectories of model: {i}")
    modelSet[i].get_unique_trajectories()
    all_trajSet[i] = modelSet[i].trajectories.copy()
# Out:
# Get single-cell trajectories of model: 0
# tracked cell 50891, 25 tracks, 46600 left
# tracked cell 50763, 23 tracks, 42400 left
# tracked cell 50735, 51 tracks, 41500 left
# tracked cell 50076, 1 tracks, 37700 left
# tracked cell 49741, 1 tracks, 37600 left
# tracked cell 49307, 1 tracks, 37500 left
# tracked cell 49056, 18 tracks, 37400 left
# tracked cell 48763, 1 tracks, 37100 left
# tracked cell 48214, 1 tracks, 36900 left
# tracked cell 48008, 1 tracks, 36800 left
# tracked cell 47562, 1 tracks, 36500 left
# tracked cell 46286, 1 tracks, 35900 left
# tracked cell 46119, 3 tracks, 35700 left
# tracked cell 45624, 1 tracks, 35600 left
# tracked cell 42924, 7 tracks, 34200 left
# tracked cell 41889, 2 tracks, 33800 left
# tracked cell 41728, 1 tracks, 33700 left
# tracked cell 40948, 1 tracks, 33300 left
# tracked cell 39770, 1 tracks, 32900 left
# tracked cell 39018, 1 tracks, 32500 left
# tracked cell 38257, 1 tracks, 32300 left
# tracked cell 38063, 6 tracks, 32200 left
# tracked cell 37504, 1 tracks, 32000 left
# tracked cell 35855, 2 tracks, 31300 left
# tracked cell 33927, 2 tracks, 30800 left
# tracked cell 32093, 1 tracks, 30400 left
# tracked cell 31650, 1 tracks, 30300 left
# tracked cell 31229, 1 tracks, 30100 left
# tracked cell 30883, 1 tracks, 29900 left
# tracked cell 30677, 1 tracks, 29700 left
# tracked cell 30610, 1 tracks, 29500 left
# tracked cell 30485, 1 tracks, 29300 left
# tracked cell 30433, 1 tracks, 29200 left
# tracked cell 30393, 30 tracks, 28600 left
# tracked cell 30344, 22 tracks, 27400 left
# tracked cell 30284, 2 tracks, 26100 left
# tracked cell 30163, 7 tracks, 22700 left
# tracked cell 29620, 1 tracks, 20400 left
# tracked cell 28426, 1 tracks, 19700 left
# tracked cell 25404, 1 tracks, 17900 left
# tracked cell 25234, 1 tracks, 17800 left
# tracked cell 23430, 1 tracks, 16800 left
# tracked cell 23224, 14 tracks, 16700 left
# tracked cell 21422, 1 tracks, 15400 left
# tracked cell 20427, 108 tracks, 14800 left
# tracked cell 20043, 1 tracks, 14400 left
# tracked cell 18724, 1 tracks, 13100 left
# tracked cell 17030, 6 tracks, 11800 left
# tracked cell 14399, 1 tracks, 9900 left
# tracked cell 12567, 1 tracks, 8300 left
# tracked cell 12195, 2 tracks, 8100 left
# tracked cell 11922, 1 tracks, 7900 left
# tracked cell 11852, 13 tracks, 7700 left
# tracked cell 11151, 1 tracks, 6800 left
# tracked cell 10635, 24 tracks, 6300 left
# tracked cell 9112, 1 tracks, 5300 left
# tracked cell 8080, 1 tracks, 4400 left
# tracked cell 6358, 16 tracks, 3100 left
# tracked cell 3593, 1 tracks, 1100 left
# tracked cell 2900, 1 tracks, 700 left
# tracked cell 584, 3 tracks, 100 left
# tracked cell 13, 1 tracks, 0 left
# Get single-cell trajectories of model: 1
# tracked cell 97681, 99 tracks, 96000 left
# tracked cell 97491, 26 tracks, 88600 left
# tracked cell 97080, 1 tracks, 70500 left
# tracked cell 97030, 1 tracks, 69600 left
# tracked cell 96323, 1 tracks, 69200 left
# tracked cell 95568, 1 tracks, 68800 left
# tracked cell 94699, 1 tracks, 68200 left
# tracked cell 94670, 3 tracks, 68100 left
# tracked cell 94178, 1 tracks, 67300 left
# tracked cell 92330, 2 tracks, 66100 left
# tracked cell 92141, 5 tracks, 65900 left
# tracked cell 92088, 1 tracks, 65800 left
# tracked cell 91522, 1 tracks, 65600 left
# tracked cell 90715, 1 tracks, 64800 left
# tracked cell 89955, 19 tracks, 63900 left
# tracked cell 88654, 1 tracks, 62700 left
# tracked cell 88173, 2 tracks, 62600 left
# tracked cell 87958, 1 tracks, 62400 left
# tracked cell 87425, 36 tracks, 61900 left
# tracked cell 86624, 1 tracks, 61200 left
# tracked cell 86238, 1 tracks, 60900 left
# tracked cell 83339, 1 tracks, 58900 left
# tracked cell 83179, 1 tracks, 58800 left
# tracked cell 82861, 1 tracks, 58500 left
# tracked cell 82420, 2 tracks, 58200 left
# tracked cell 80979, 5 tracks, 56800 left
# tracked cell 80711, 1 tracks, 56500 left
# tracked cell 79676, 1 tracks, 55600 left
# tracked cell 79418, 1 tracks, 55500 left
# tracked cell 79117, 1 tracks, 54900 left
# tracked cell 78621, 1 tracks, 54500 left
# tracked cell 77494, 1 tracks, 53800 left
# tracked cell 77121, 1 tracks, 53600 left
# tracked cell 76980, 1 tracks, 53300 left
# tracked cell 75727, 5 tracks, 52400 left
# tracked cell 74030, 1 tracks, 51100 left
# tracked cell 73214, 1 tracks, 50300 left
# tracked cell 72535, 1 tracks, 49600 left
# tracked cell 71260, 1 tracks, 48600 left
# tracked cell 71056, 22 tracks, 48400 left
# tracked cell 70671, 1 tracks, 48100 left
# tracked cell 70187, 1 tracks, 48000 left
# tracked cell 69727, 1 tracks, 47500 left
# tracked cell 68860, 1 tracks, 46900 left
# tracked cell 68264, 1 tracks, 46500 left
# tracked cell 67676, 1 tracks, 46100 left
# tracked cell 67035, 2 tracks, 45500 left
# tracked cell 66623, 1 tracks, 45000 left
# tracked cell 66298, 2 tracks, 44700 left
# tracked cell 66059, 2 tracks, 44400 left
# tracked cell 65290, 1 tracks, 44000 left
# tracked cell 64095, 1 tracks, 43200 left
# tracked cell 63545, 1 tracks, 42600 left
# tracked cell 63356, 1 tracks, 42500 left
# tracked cell 62361, 1 tracks, 41900 left
# tracked cell 61737, 1 tracks, 41600 left
# tracked cell 61331, 3 tracks, 41500 left
# tracked cell 61101, 1 tracks, 41400 left
# tracked cell 60784, 109 tracks, 41000 left
# tracked cell 60696, 25 tracks, 40800 left
# tracked cell 59762, 1 tracks, 39900 left
# tracked cell 59059, 1 tracks, 39200 left
# tracked cell 58908, 1 tracks, 39100 left
# tracked cell 56926, 1 tracks, 37700 left
# tracked cell 56639, 1 tracks, 37600 left
# tracked cell 56163, 7 tracks, 37300 left
# tracked cell 56007, 1 tracks, 37200 left
# tracked cell 55234, 84 tracks, 36500 left
# tracked cell 54259, 1 tracks, 36100 left
# tracked cell 53797, 1 tracks, 35500 left
# tracked cell 53423, 1 tracks, 35300 left
# tracked cell 53081, 3 tracks, 35100 left
# tracked cell 51653, 1 tracks, 34400 left
# tracked cell 50068, 1 tracks, 32800 left
# tracked cell 48424, 1 tracks, 31400 left
# tracked cell 48021, 1 tracks, 30800 left
# tracked cell 47039, 1 tracks, 30300 left
# tracked cell 46643, 89 tracks, 29900 left
# tracked cell 45311, 1 tracks, 29000 left
# tracked cell 44820, 1 tracks, 28800 left
# tracked cell 43731, 1 tracks, 28200 left
# tracked cell 42761, 1 tracks, 27000 left
# tracked cell 41737, 1 tracks, 26100 left
# tracked cell 41417, 1 tracks, 26000 left
# tracked cell 41225, 1 tracks, 25800 left
# tracked cell 41058, 3 tracks, 25600 left
# tracked cell 40905, 1 tracks, 25400 left
# tracked cell 40794, 1 tracks, 25200 left
# tracked cell 37548, 1 tracks, 22600 left
# tracked cell 37277, 1 tracks, 22500 left
# tracked cell 35989, 1 tracks, 21800 left
# tracked cell 35839, 1 tracks, 21700 left
# tracked cell 34620, 15 tracks, 20700 left
# tracked cell 34455, 1 tracks, 20600 left
# tracked cell 33974, 2 tracks, 20300 left
# tracked cell 33006, 1 tracks, 19600 left
# tracked cell 32665, 1 tracks, 19400 left
# tracked cell 32540, 1 tracks, 19300 left
# tracked cell 29825, 1 tracks, 17600 left
# tracked cell 29658, 1 tracks, 17500 left
# tracked cell 29254, 1 tracks, 17400 left
# tracked cell 28927, 1 tracks, 17300 left
# tracked cell 28659, 11 tracks, 17200 left
# tracked cell 28191, 1 tracks, 17000 left
# tracked cell 27113, 1 tracks, 16300 left
# tracked cell 26845, 1 tracks, 16200 left
# tracked cell 26684, 1 tracks, 16000 left
# tracked cell 26345, 12 tracks, 15800 left
# tracked cell 24931, 1 tracks, 14800 left
# tracked cell 24608, 1 tracks, 14500 left
# tracked cell 22812, 1 tracks, 13300 left
# tracked cell 22631, 1 tracks, 13200 left
# tracked cell 21092, 1 tracks, 12100 left
# tracked cell 19166, 1 tracks, 10900 left
# tracked cell 18999, 1 tracks, 10800 left
# tracked cell 18638, 1 tracks, 10600 left
# tracked cell 18348, 1 tracks, 10400 left
# tracked cell 17373, 1 tracks, 10000 left
# tracked cell 16958, 1 tracks, 9800 left
# tracked cell 16729, 4 tracks, 9700 left
# tracked cell 16140, 1 tracks, 9500 left
# tracked cell 14944, 3 tracks, 8900 left
# tracked cell 14639, 1 tracks, 8800 left
# tracked cell 14264, 2 tracks, 8700 left
# tracked cell 13710, 1 tracks, 8500 left
# tracked cell 13132, 1 tracks, 8300 left
# tracked cell 11401, 1 tracks, 7500 left
# tracked cell 11018, 1 tracks, 7300 left
# tracked cell 10055, 1 tracks, 7000 left
# tracked cell 9779, 3 tracks, 6900 left
# tracked cell 9425, 1 tracks, 6800 left
# tracked cell 9199, 1 tracks, 6700 left
# tracked cell 9001, 2 tracks, 6600 left
# tracked cell 8524, 17 tracks, 6500 left
# tracked cell 8075, 1 tracks, 6400 left
# tracked cell 7825, 1 tracks, 6300 left
# tracked cell 7348, 18 tracks, 5700 left
# tracked cell 7226, 11 tracks, 4900 left
# tracked cell 7084, 1 tracks, 4100 left
# tracked cell 6728, 1 tracks, 4000 left
# tracked cell 6367, 1 tracks, 3900 left
# tracked cell 6006, 1 tracks, 3800 left
# tracked cell 5606, 1 tracks, 3700 left
# tracked cell 5163, 1 tracks, 3600 left
# tracked cell 4812, 1 tracks, 3500 left
# tracked cell 4440, 1 tracks, 3400 left
# tracked cell 4133, 1 tracks, 3300 left
# tracked cell 3709, 6 tracks, 3100 left
# tracked cell 3618, 2 tracks, 2700 left
# tracked cell 3377, 5 tracks, 1900 left
# tracked cell 3038, 1 tracks, 1800 left
# tracked cell 2020, 1 tracks, 1500 left
# tracked cell 1462, 1 tracks, 1300 left
# tracked cell 1286, 1 tracks, 1100 left
# tracked cell 1213, 1 tracks, 1000 left
# tracked cell 983, 3 tracks, 600 left
# tracked cell 837, 3 tracks, 300 left
# tracked cell 795, 3 tracks, 200 left
# tracked cell 754, 3 tracks, 100 left
# tracked cell 16, 1 tracks, 0 left
# Get single-cell trajectories of model: 2
# tracked cell 58422, 15 tracks, 52700 left
# tracked cell 58369, 87 tracks, 50800 left
# tracked cell 58285, 1 tracks, 47300 left
# tracked cell 58204, 3 tracks, 44000 left
# tracked cell 57130, 1 tracks, 38700 left
# tracked cell 54914, 1 tracks, 37500 left
# tracked cell 54466, 1 tracks, 37300 left
# tracked cell 54308, 1 tracks, 37200 left
# tracked cell 52746, 6 tracks, 36200 left
# tracked cell 51681, 1 tracks, 35000 left
# tracked cell 51158, 1 tracks, 34800 left
# tracked cell 50725, 1 tracks, 34400 left
# tracked cell 49844, 1 tracks, 33900 left
# tracked cell 49009, 2 tracks, 33200 left
# tracked cell 48909, 47 tracks, 33100 left
# tracked cell 47750, 1 tracks, 32500 left
# tracked cell 46883, 1 tracks, 31900 left
# tracked cell 46539, 1 tracks, 31600 left
# tracked cell 44935, 1 tracks, 30300 left
# tracked cell 44547, 1 tracks, 29900 left
# tracked cell 43678, 1 tracks, 29400 left
# tracked cell 42950, 1 tracks, 29000 left
# tracked cell 42165, 1 tracks, 28600 left
# tracked cell 40632, 1 tracks, 27900 left
# tracked cell 39878, 1 tracks, 27600 left
# tracked cell 39381, 1 tracks, 27300 left
# tracked cell 38366, 1 tracks, 26900 left
# tracked cell 37991, 1 tracks, 26600 left
# tracked cell 37620, 1 tracks, 26400 left
# tracked cell 37246, 1 tracks, 26300 left
# tracked cell 36648, 2 tracks, 25400 left
# tracked cell 35790, 1 tracks, 24900 left
# tracked cell 35473, 1 tracks, 24800 left
# tracked cell 34788, 1 tracks, 24500 left
# tracked cell 34545, 55 tracks, 24300 left
# tracked cell 34392, 1 tracks, 24200 left
# tracked cell 34008, 3 tracks, 24100 left
# tracked cell 33705, 2 tracks, 23900 left
# tracked cell 33424, 3 tracks, 23800 left
# tracked cell 31344, 12 tracks, 22500 left
# tracked cell 30495, 17 tracks, 22000 left
# tracked cell 30319, 1 tracks, 21900 left
# tracked cell 29633, 1 tracks, 21500 left
# tracked cell 29347, 1 tracks, 21400 left
# tracked cell 29032, 1 tracks, 21300 left
# tracked cell 28468, 1 tracks, 21100 left
# tracked cell 28112, 1 tracks, 20900 left
# tracked cell 27833, 1 tracks, 20700 left
# tracked cell 27514, 1 tracks, 20500 left
# tracked cell 27099, 2 tracks, 20300 left
# tracked cell 26630, 1 tracks, 19800 left
# tracked cell 25996, 2 tracks, 19300 left
# tracked cell 24600, 5 tracks, 18200 left
# tracked cell 24303, 1 tracks, 18000 left
# tracked cell 23985, 1 tracks, 17700 left
# tracked cell 23676, 3 tracks, 17600 left
# tracked cell 23437, 1 tracks, 17400 left
# tracked cell 22870, 1 tracks, 17000 left
# tracked cell 22569, 1 tracks, 16800 left
# tracked cell 22309, 1 tracks, 16600 left
# tracked cell 22009, 1 tracks, 16500 left
# tracked cell 19682, 1 tracks, 15200 left
# tracked cell 19501, 1 tracks, 15100 left
# tracked cell 19342, 1 tracks, 14900 left
# tracked cell 18819, 2 tracks, 14700 left
# tracked cell 18310, 9 tracks, 14100 left
# tracked cell 17832, 3 tracks, 13700 left
# tracked cell 17377, 1 tracks, 13500 left
# tracked cell 15268, 1 tracks, 12000 left
# tracked cell 13861, 3 tracks, 11400 left
# tracked cell 13145, 1 tracks, 10800 left
# tracked cell 12883, 14 tracks, 10600 left
# tracked cell 11879, 2 tracks, 10200 left
# tracked cell 11731, 3 tracks, 10100 left
# tracked cell 11346, 2 tracks, 10000 left
# tracked cell 10886, 1 tracks, 9800 left
# tracked cell 10551, 1 tracks, 9700 left
# tracked cell 10082, 1 tracks, 9500 left
# tracked cell 9851, 4 tracks, 9200 left
# tracked cell 9507, 1 tracks, 8900 left
# tracked cell 9243, 2 tracks, 8800 left
# tracked cell 8984, 2 tracks, 8700 left
# tracked cell 8637, 1 tracks, 8300 left
# tracked cell 8407, 5 tracks, 8000 left
# tracked cell 8216, 1 tracks, 7300 left
# tracked cell 7915, 7 tracks, 7200 left
# tracked cell 7735, 1 tracks, 7100 left
# tracked cell 7430, 1 tracks, 6800 left
# tracked cell 6662, 1 tracks, 6400 left
# tracked cell 6430, 1 tracks, 6300 left
# tracked cell 6335, 1 tracks, 6200 left
# tracked cell 6259, 1 tracks, 6100 left
# tracked cell 6156, 1 tracks, 6000 left
# tracked cell 6070, 1 tracks, 5900 left
# tracked cell 5980, 1 tracks, 5800 left
# tracked cell 5848, 3 tracks, 5600 left
# tracked cell 5712, 1 tracks, 5500 left
# tracked cell 5402, 2 tracks, 5100 left
# tracked cell 5084, 1 tracks, 4800 left
# tracked cell 4959, 1 tracks, 4500 left
# tracked cell 4435, 1 tracks, 2600 left
# tracked cell 3901, 4 tracks, 2400 left
# tracked cell 3125, 4 tracks, 2100 left
# tracked cell 2888, 1 tracks, 2000 left
# tracked cell 2256, 1 tracks, 1800 left
# tracked cell 2126, 2 tracks, 1700 left
# tracked cell 1805, 1 tracks, 1400 left
# tracked cell 1217, 1 tracks, 400 left
# tracked cell 574, 2 tracks, 200 left
# tracked cell 146, 1 tracks, 100 left
# tracked cell 0, 1 tracks, 0 left
# Get single-cell trajectories of model: 3
# tracked cell 67817, 18 tracks, 67500 left
# tracked cell 67776, 10 tracks, 66600 left
# tracked cell 67600, 36 tracks, 61300 left
# tracked cell 67377, 107 tracks, 53500 left
# tracked cell 67321, 25 tracks, 51900 left
# tracked cell 66628, 1 tracks, 49300 left
# tracked cell 66041, 1 tracks, 48900 left
# tracked cell 65772, 1 tracks, 48700 left
# tracked cell 65500, 1 tracks, 48400 left
# tracked cell 64746, 1 tracks, 47900 left
# tracked cell 64251, 1 tracks, 47700 left
# tracked cell 63661, 4 tracks, 47400 left
# tracked cell 63314, 1 tracks, 47100 left
# tracked cell 62834, 1 tracks, 46800 left
# tracked cell 62292, 25 tracks, 46600 left
# tracked cell 61915, 1 tracks, 46200 left
# tracked cell 60408, 6 tracks, 45200 left
# tracked cell 59201, 1 tracks, 44400 left
# tracked cell 57542, 1 tracks, 42800 left
# tracked cell 53503, 4 tracks, 40100 left
# tracked cell 51544, 14 tracks, 39100 left
# tracked cell 51071, 2 tracks, 38900 left
# tracked cell 50813, 1 tracks, 38700 left
# tracked cell 49655, 1 tracks, 37500 left
# tracked cell 49342, 1 tracks, 37300 left
# tracked cell 47174, 1 tracks, 35900 left
# tracked cell 46978, 7 tracks, 35800 left
# tracked cell 46767, 31 tracks, 35700 left
# tracked cell 45867, 1 tracks, 35100 left
# tracked cell 45275, 64 tracks, 34700 left
# tracked cell 44649, 4 tracks, 34300 left
# tracked cell 42712, 1 tracks, 32900 left
# tracked cell 42517, 30 tracks, 32800 left
# tracked cell 42175, 1 tracks, 32500 left
# tracked cell 41330, 1 tracks, 31200 left
# tracked cell 41107, 1 tracks, 31100 left
# tracked cell 41014, 2 tracks, 31000 left
# tracked cell 40313, 1 tracks, 30200 left
# tracked cell 37601, 2 tracks, 28900 left
# tracked cell 37411, 1 tracks, 28700 left
# tracked cell 35160, 1 tracks, 27500 left
# tracked cell 34754, 4 tracks, 27300 left
# tracked cell 34483, 1 tracks, 27200 left
# tracked cell 34240, 1 tracks, 27000 left
# tracked cell 32579, 1 tracks, 25800 left
# tracked cell 31863, 1 tracks, 24900 left
# tracked cell 29807, 1 tracks, 23500 left
# tracked cell 28025, 1 tracks, 22400 left
# tracked cell 26145, 11 tracks, 21500 left
# tracked cell 25965, 1 tracks, 21300 left
# tracked cell 22187, 1 tracks, 19100 left
# tracked cell 21953, 16 tracks, 19000 left
# tracked cell 20828, 6 tracks, 18500 left
# tracked cell 20404, 1 tracks, 18300 left
# tracked cell 17690, 1 tracks, 17100 left
# tracked cell 17394, 1 tracks, 17000 left
# tracked cell 17285, 1 tracks, 16900 left
# tracked cell 17066, 8 tracks, 16400 left
# tracked cell 16587, 1 tracks, 14100 left
# tracked cell 16152, 2 tracks, 13800 left
# tracked cell 14528, 6 tracks, 13100 left
# tracked cell 13153, 1 tracks, 12600 left
# tracked cell 12859, 1 tracks, 12400 left
# tracked cell 12774, 1 tracks, 12300 left
# tracked cell 12664, 1 tracks, 12100 left
# tracked cell 12626, 1 tracks, 12000 left
# tracked cell 12593, 47 tracks, 11600 left
# tracked cell 12428, 5 tracks, 8800 left
# tracked cell 12354, 43 tracks, 7300 left
# tracked cell 11909, 33 tracks, 6800 left
# tracked cell 11427, 50 tracks, 6500 left
# tracked cell 10235, 21 tracks, 5800 left
# tracked cell 9891, 2 tracks, 5500 left
# tracked cell 9623, 1 tracks, 5100 left
# tracked cell 9171, 1 tracks, 4700 left
# tracked cell 8153, 2 tracks, 3800 left
# tracked cell 6486, 1 tracks, 2800 left
# tracked cell 6326, 1 tracks, 2700 left
# tracked cell 6036, 2 tracks, 2500 left
# tracked cell 5142, 2 tracks, 1900 left
# tracked cell 2199, 7 tracks, 500 left
# tracked cell 1911, 3 tracks, 400 left
# tracked cell 682, 4 tracks, 100 left
# tracked cell 13, 1 tracks, 0 left
# Get single-cell trajectories of model: 4
# tracked cell 57760, 55 tracks, 55500 left
# tracked cell 57741, 7 tracks, 55000 left
# tracked cell 57694, 28 tracks, 53200 left
# tracked cell 57522, 21 tracks, 46500 left
# tracked cell 57506, 4 tracks, 45900 left
# tracked cell 57492, 13 tracks, 45300 left
# tracked cell 56834, 2 tracks, 41500 left
# tracked cell 56363, 1 tracks, 41100 left
# tracked cell 55866, 1 tracks, 40800 left
# tracked cell 55849, 90 tracks, 40700 left
# tracked cell 55401, 1 tracks, 40400 left
# tracked cell 54918, 1 tracks, 40200 left
# tracked cell 53665, 1 tracks, 39300 left
# tracked cell 53462, 1 tracks, 39200 left
# tracked cell 52552, 1 tracks, 38700 left
# tracked cell 52077, 1 tracks, 38600 left
# tracked cell 51610, 1 tracks, 38400 left
# tracked cell 51195, 1 tracks, 38200 left
# tracked cell 49782, 1 tracks, 37100 left
# tracked cell 49325, 1 tracks, 36700 left
# tracked cell 48992, 1 tracks, 36400 left
# tracked cell 48873, 1 tracks, 36300 left
# tracked cell 47964, 1 tracks, 35800 left
# tracked cell 47810, 1 tracks, 35700 left
# tracked cell 47479, 1 tracks, 35600 left
# tracked cell 47263, 1 tracks, 35400 left
# tracked cell 47007, 1 tracks, 35200 left
# tracked cell 46591, 1 tracks, 35000 left
# tracked cell 44747, 1 tracks, 34000 left
# tracked cell 44553, 1 tracks, 33900 left
# tracked cell 43934, 1 tracks, 33500 left
# tracked cell 41227, 1 tracks, 31100 left
# tracked cell 41030, 1 tracks, 30900 left
# tracked cell 40602, 1 tracks, 30700 left
# tracked cell 40215, 1 tracks, 30500 left
# tracked cell 39318, 1 tracks, 30000 left
# tracked cell 38558, 31 tracks, 29400 left
# tracked cell 38251, 1 tracks, 29200 left
# tracked cell 37446, 1 tracks, 28700 left
# tracked cell 37188, 5 tracks, 28500 left
# tracked cell 36609, 1 tracks, 28200 left
# tracked cell 36261, 1 tracks, 27900 left
# tracked cell 35878, 1 tracks, 27600 left
# tracked cell 35162, 1 tracks, 26800 left
# tracked cell 34470, 1 tracks, 26300 left
# tracked cell 33254, 1 tracks, 25600 left
# tracked cell 33059, 1 tracks, 25400 left
# tracked cell 32363, 1 tracks, 24900 left
# tracked cell 31998, 1 tracks, 24700 left
# tracked cell 30996, 1 tracks, 24100 left
# tracked cell 30137, 1 tracks, 23700 left
# tracked cell 29789, 1 tracks, 23500 left
# tracked cell 28464, 1 tracks, 22600 left
# tracked cell 28002, 1 tracks, 22300 left
# tracked cell 27234, 22 tracks, 21900 left
# tracked cell 27037, 1 tracks, 21800 left
# tracked cell 26686, 3 tracks, 21700 left
# tracked cell 26320, 2 tracks, 21600 left
# tracked cell 25510, 1 tracks, 21200 left
# tracked cell 24515, 1 tracks, 20500 left
# tracked cell 24262, 1 tracks, 20400 left
# tracked cell 24214, 1 tracks, 20300 left
# tracked cell 23920, 1 tracks, 20200 left
# tracked cell 23393, 8 tracks, 19800 left
# tracked cell 23302, 1 tracks, 19700 left
# tracked cell 22988, 2 tracks, 19600 left
# tracked cell 22716, 1 tracks, 19400 left
# tracked cell 22392, 1 tracks, 19200 left
# tracked cell 21513, 1 tracks, 18600 left
# tracked cell 21179, 2 tracks, 18400 left
# tracked cell 20700, 2 tracks, 18100 left
# tracked cell 20433, 6 tracks, 18000 left
# tracked cell 19978, 6 tracks, 17800 left
# tracked cell 19525, 1 tracks, 17600 left
# tracked cell 18993, 1 tracks, 17300 left
# tracked cell 18717, 1 tracks, 17200 left
# tracked cell 18523, 1 tracks, 17100 left
# tracked cell 17953, 2 tracks, 16900 left
# tracked cell 17378, 1 tracks, 16700 left
# tracked cell 17130, 1 tracks, 16600 left
# tracked cell 16516, 1 tracks, 16300 left
# tracked cell 16302, 1 tracks, 16000 left
# tracked cell 16020, 71 tracks, 12700 left
# tracked cell 14711, 2 tracks, 10200 left
# tracked cell 13027, 1 tracks, 8600 left
# tracked cell 12274, 1 tracks, 7900 left
# tracked cell 11761, 1 tracks, 7700 left
# tracked cell 11119, 1 tracks, 7300 left
# tracked cell 10899, 1 tracks, 7200 left
# tracked cell 9308, 5 tracks, 5500 left
# tracked cell 8873, 1 tracks, 5200 left
# tracked cell 7929, 31 tracks, 4300 left
# tracked cell 7577, 2 tracks, 4000 left
# tracked cell 6945, 1 tracks, 3400 left
# tracked cell 5528, 2 tracks, 2600 left
# tracked cell 4416, 1 tracks, 2000 left
# tracked cell 4258, 6 tracks, 1900 left
# tracked cell 2822, 16 tracks, 900 left
# tracked cell 2000, 9 tracks, 600 left
# tracked cell 724, 1 tracks, 100 left
# tracked cell 10, 1 tracks, 0 left
# Get single-cell trajectories of model: 5
# tracked cell 45973, 44 tracks, 42200 left
# tracked cell 45927, 83 tracks, 40900 left
# tracked cell 45826, 38 tracks, 37200 left
# tracked cell 45754, 27 tracks, 34700 left
# tracked cell 45664, 7 tracks, 30600 left
# tracked cell 45336, 1 tracks, 30200 left
# tracked cell 44685, 1 tracks, 29900 left
# tracked cell 44561, 1 tracks, 29800 left
# tracked cell 43621, 1 tracks, 29100 left
# tracked cell 42941, 44 tracks, 28700 left
# tracked cell 40409, 1 tracks, 26500 left
# tracked cell 40057, 1 tracks, 26400 left
# tracked cell 38518, 2 tracks, 25900 left
# tracked cell 36392, 1 tracks, 24600 left
# tracked cell 35580, 1 tracks, 24200 left
# tracked cell 33466, 89 tracks, 23000 left
# tracked cell 32837, 11 tracks, 22500 left
# tracked cell 31823, 58 tracks, 22200 left
# tracked cell 23996, 1 tracks, 16000 left
# tracked cell 23163, 45 tracks, 15400 left
# tracked cell 22760, 22 tracks, 15000 left
# tracked cell 22608, 1 tracks, 14900 left
# tracked cell 22162, 1 tracks, 14300 left
# tracked cell 18561, 1 tracks, 12700 left
# tracked cell 16913, 1 tracks, 11400 left
# tracked cell 16882, 20 tracks, 11200 left
# tracked cell 15754, 18 tracks, 10400 left
# tracked cell 14498, 1 tracks, 9400 left
# tracked cell 14043, 14 tracks, 9100 left
# tracked cell 12605, 21 tracks, 8100 left
# tracked cell 11986, 2 tracks, 7600 left
# tracked cell 10818, 2 tracks, 6600 left
# tracked cell 9920, 3 tracks, 5900 left
# tracked cell 9636, 1 tracks, 5600 left
# tracked cell 9488, 1 tracks, 5500 left
# tracked cell 8908, 8 tracks, 5000 left
# tracked cell 3988, 1 tracks, 1500 left
# tracked cell 3170, 8 tracks, 1100 left
# tracked cell 720, 1 tracks, 100 left
# tracked cell 20, 1 tracks, 0 left

# %% [markdown]
# ## Load Cell Features & Labels Extracted from O2VAE (https://github.com/directysj/o2vae.git)

# %%
latent_dim=256 # Latent (Bottleneck) Dimension of Variational Auto-encoder 
for i in indgood_models:
    data_vae = np.load(f'../o2vae/features_vae{latent_dim}_{sysName[:-1]}{fovs[i]}.npz')
    features_vae = data_vae['embeddings']
    #labels_vae = data_vae['labels']
    modelSet[i].Xf_vae = features_vae
    #cell2cell_interaction_features = modelSet[i].Xf[:, 77:]
    #modelSet[i].Xf_new = np.concatenate((modelSet[i].Xf_vae, cell2cell_interaction_features), axis=1)

# %%
# Get snippets along with their full single-cell trajectory indices  
def get_snippets_with_traj_inds(self, seg_length): 
    n_sctraj = len(self.trajectories) # Number of Single-Cell Trajectories 
    traj_segSet = np.zeros((0, seg_length)).astype(int)
    ind_map_snippet_fulltraj = np.array([])
    for ind_traj in range(n_sctraj):
        cell_traj = self.trajectories[ind_traj] # Select a single-cell trajectory
        traj_len = cell_traj.size
        #print("Length of a Single-Cell Trajectory:",traj_len)
        if traj_len >= seg_length:
            for ic in range(traj_len - seg_length):
                traj_seg = cell_traj[ic:ic+seg_length]
                traj_segSet = np.append(traj_segSet, traj_seg[np.newaxis, :], axis = 0)
                # Save indices of all snippets corresponding to "FULL" single-cell trajectory 
                ind_map_snippet_fulltraj = np.append(ind_map_snippet_fulltraj, ind_traj)
                #print("Indices to map snippets to the full trajectory:",ind_map_snippet_fulltraj)
    return ind_map_snippet_fulltraj, traj_segSet

# %% [markdown]
# ## Single-cell Trajectories Over The Cell Features

# %%
trajectory_lengths = np.array([1, 4, 8, 20, 40])

# %%
trajl = trajectory_lengths[0]
Xf_traj = np.zeros((0, modelSet[0].Xf_vae.shape[1]*trajl))
indtreatment_traj = np.array([])
indstack_traj = np.array([])
indframes_traj = np.array([])
indmodel_traj_snippets = np.array([])
for i in indgood_models:
    print(f'Building trajectory data for model: {i}')
    modelSet[i].trajectories = all_trajSet[i].copy() # ALL Single-Cell trajectories 
    modelSet[i].trajl = trajl # Trajectory snippet length 
    # Get trajectory snippets of (all trajectories) a given length in a sliding window and mapped with single-cell trajectory indices 
    modelSet[i].snippet_map_fulltraj_inds, modelSet[i].traj = get_snippets_with_traj_inds(modelSet[i], trajl)
    # Xpca (feature info) along the single-cell trajectory snippets, extracted directly from cell indices unique within a 'model' 
    data = modelSet[i].Xf_vae[modelSet[i].traj, :] 
    #data = modelSet[i].Xf_new[modelSet[i].traj, :]
    #datacom = modelSet[i].Xf_com[modelSet[i].traj, :]
    data = data.reshape(modelSet[i].traj.shape[0], modelSet[i].Xf_vae.shape[1]*trajl)
    #data = data.reshape(modelSet[i].traj.shape[0], modelSet[i].Xf_new.shape[1]*trajl)
    #datacom = datacom.reshape(modelSet[i].traj.shape[0], modelSet[i].Xf_com.shape[1]*trajl)
    #data = np.append(data, datacom, axis = 1)
    indgood = np.where(np.sum(np.isnan(data), axis = 1) == 0)[0] # Consider models as "Good" that don't have NaN in "data" 
    data = data[indgood, :]
    modelSet[i].traj = modelSet[i].traj[indgood, :] # Cleaned trajectory snippets if any NaN 
    modelSet[i].snippet_map_fulltraj_inds = modelSet[i].snippet_map_fulltraj_inds[indgood]
    # Store all trajectory snippets of a given length (picked in a sliding window) 
    Xf_traj = np.append(Xf_traj, data, axis = 0) 
    indtreatment_traj = np.append(indtreatment_traj, i*np.ones(data.shape[0])) # Indices of Treatments (Models) Along Trajectory Snippets 
    indstacks = modelSet[i].cells_imgfileSet[modelSet[i].traj[:, 0]]
    indstack_traj = np.append(indstack_traj, indstacks)
    ind_frames = modelSet[i].cells_frameSet[modelSet[i].traj[:, 0]].astype(int) # Frame indices at the start of snippets
    ind_frames = ind_frames + trajl # Frame indices at the end of snippets
    indframes_traj = np.append(indframes_traj, ind_frames) # Starting Frame Indices of ALL snippets
    indtraj_snippets = modelSet[i].snippet_map_fulltraj_inds
    indmodel_traj_snippets = np.append(indmodel_traj_snippets, indtraj_snippets) # Save for all models: map of snippets to the sc trajectories
# Out:
# Building trajectory data for model: 0
# Building trajectory data for model: 1
# Building trajectory data for model: 2
# Building trajectory data for model: 3
# Building trajectory data for model: 4
# Building trajectory data for model: 5

# %%
def get_cellCycInfoTrajs(file_info):
    with open(file_info, 'r') as fp:
        lines = fp.readlines()

    nuc2cytoRatio = []
    CC_vals = []
    frames = []

    for line1, line2, line3 in zip(lines[::3], lines[1::3], lines[2::3]):
        line1 = np.array(line1.strip()[1:-1].split(', '), dtype=float)
        line2 = np.array(line2.strip()[1:-1].split(', '), dtype=float)
        line3 = np.array(line3.strip()[1:-1].split(', '), dtype=int)

        mask = ~np.isnan(line1)
        line1 = line1[mask]
        line2 = line2[mask]
        line3 = line3[mask]

        nuc2cytoRatio.append(line1)
        CC_vals.append(line2)
        frames.append(line3)

    return nuc2cytoRatio, CC_vals, frames

# %%
file_path = '/home/groups/ZuckermanLab/jalim/LI204601_INCUCYTE/cellCycInfoRawReporterImgs/'
sname_reporter = "LI204601_G"

# %% [markdown]
# ## Get Nuc/Cyto Ratios and CC values along all single-cell trajectories

# %%
X = [None] * nfovs
y = [None] * nfovs

for i in range(nfovs):
    # Get cross-correlation values along all single-cell trajectories  
    cc_filename = f"{file_path}{sname_reporter}_{fovs[i]}.dat"
    n2c_ratio, cc_vals, frame_numbers = get_cellCycInfoTrajs(cc_filename)

    valid_indstm = []
    nuc2Cyto_ratio_last_frames = []
    model_indc = i
    indstm = np.where(indtreatment_traj == model_indc)[0]
    fid_snippets = indframes_traj[indstm].astype(int) # Map frame indices of snippets
    indc_map_fulltraj_snippets = indmodel_traj_snippets[indstm].astype(int) # Map Indices of Full Trajectory to Snippets 
    
    for j, ind_fulltraj in enumerate(indc_map_fulltraj_snippets):
        # Look for a snippet frame within its full trajectory
        possible_indices = np.where(frame_numbers[ind_fulltraj] == fid_snippets[j])[0]
        if len(possible_indices) > 0:
            nbc_ratio = n2c_ratio[ind_fulltraj][possible_indices[0]]
            nuc2Cyto_ratio_last_frames.append(nbc_ratio)
            valid_indstm.append(indstm[j]) 
         
    nuc2Cyto_ratio_last_frames = np.array(nuc2Cyto_ratio_last_frames)
    X[i] = Xf_traj[valid_indstm]  # Use the valid indices to index into Xf_traj
    y[i] = nuc2Cyto_ratio_last_frames
    print(f"Preparing data of {fovs[i]} field of view.")
# Out:
# Preparing data of A2_1 field of view.
# Preparing data of A2_2 field of view.
# Preparing data of A2_3 field of view.
# Preparing data of B2_1 field of view.
# Preparing data of B2_3 field of view.
# Preparing data of B2_4 field of view.

# %%
def trim_cc_vals(ratio_values, num_bins, target_density):
    df = pd.DataFrame(ratio_values, columns=['CC'])
    df['original_index'] = df.index # Include original indices in the DataFrame
    
    counts, bin_edges = np.histogram(df['CC'], bins=num_bins) # Calculate histogram without plotting
    df['bin'] = pd.cut(df['CC'], bins=bin_edges, labels=False, include_lowest=True) # Create a bin label based on the bin_edges

    trimmed_data = []
    
    for i in range(num_bins):
        bin_filter = (df['bin'] == i) # Filter the DataFrame to get data only in this bin
        bin_data = df[bin_filter]

        # If the number of items in the bin is greater than target_density, sample down
        if bin_data.shape[0] > target_density:
           sampled_data = bin_data.sample(n=target_density, random_state=42)
        else:
           sampled_data = bin_data
        trimmed_data.append(sampled_data) # Append the sampled or full bin data to the list
    
    trimmed_df = pd.concat(trimmed_data) # Concatenate all trimmed data back into a DataFrame
    trimmed_df = trimmed_df.sort_values('original_index') # Sorting by original index to preserve the original data order
    
    return trimmed_df

# %% [markdown]
# ## Split Data in Training & Test Sets

# %%
scaler_nn = MinMaxScaler() # Scale features in the range [0, 1]

fovs_indc = [i for i in range(nfovs)]
fovs_indc = np.array(fovs_indc)
fovs_inds_test = np.array([3, 4, 5])
train_fovs = np.setdiff1d(fovs_indc, fovs_inds_test)

X_train = np.zeros((0, X[0].shape[1]))
y_train = np.zeros(0)
for it_fov in train_fovs:
    X_train = np.append(X_train, X[it_fov], axis = 0)
    y_train = np.append(y_train, y[it_fov], axis = 0) # Nuc/Cyto Ratio

target_density = 2000; n_bins = 50 
############################ Trim Training Data ############################ 
trimmed_cc_train = trim_cc_vals(y_train, n_bins, target_density)
original_indices_train = []
y_train_trim = []
    
for it in range(trimmed_cc_train['original_index'].shape[0]):
    original_indices_train.append(trimmed_cc_train['original_index'].iloc[it])
    y_train_trim.append(trimmed_cc_train['CC'].iloc[it])
    
original_indices_train = np.array(original_indices_train)
y_train_trim = np.array(y_train_trim)
X_train_trim = X_train[original_indices_train, :]

######### Scale All Features in the Same Range #########
X_train_rf = scaler_nn.fit_transform(X_train_trim)

test_fov = 5
X_test = X[test_fov]
y_test = y[test_fov]
X_test_rf = scaler_nn.transform(X_test)

# %% [markdown]
# ## Visualize Training & Test Sets Data

# %%
plt.clf()
fig, axs = plt.subplots(1, 2, figsize = (20, 8))
axs = axs.flatten()

formatter = ticker.ScalarFormatter()
formatter.set_scientific(False)

axs[0].hist(y_train_trim, bins=100, density=True)
axs[0].set_xscale('log')
axs[0].set_xlabel('N/C Ratio')
axs[0].set_ylabel('Density')
axs[0].set_title('A FOVs: Training')
axs[0].xaxis.set_major_formatter(formatter)
axs[0].xaxis.set_minor_formatter(formatter)
axs[0].xaxis.set_minor_locator(ticker.MultipleLocator(0.25))

axs[1].hist(y_test, bins=100, density=True)
axs[1].set_xscale('log')
axs[1].set_xlabel('N/C Ratio')
axs[1].set_ylabel('Density')
axs[1].set_title(f'{fovs[test_fov]} FOV: Test Set')
axs[1].xaxis.set_major_formatter(formatter)
axs[1].xaxis.set_minor_formatter(formatter)
axs[1].xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
plt.tight_layout()
#plt.savefig(f"./figs/distN2Cratio_{fovs[test_fov]}_trajl{trajl}_VAE{latent_dim}.png", dpi=400, bbox_inches='tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Random Forest Regressor on VAE Features

# %%
# Note: Model Hyperparameters are selected from GridSearchCV() of Scikit-learn
model_RFreg = RandomForestRegressor(
    n_estimators=100,  # Number of trees in the forest
    max_depth=20,  # Maximum depth of the tree
    min_samples_split=2, # Minimum number of samples required to split an internal node
    min_samples_leaf=10, # Minimum number of samples required to be at a leaf node
    max_features='sqrt', # Number of features to consider when looking for the best split
    n_jobs=-1,  # Number of CPU cores to use
    random_state=42,  # Random seed for reproducibility
    verbose=0  # Verbosity level
)

cv_kFold = KFold(n_splits = 5, # n_splits fold cross-validations 
                 shuffle = True,
                 random_state = 42) # Simple K-fold Cross Validations

pipe_RFreg = Pipeline([
    ('scaler', MinMaxScaler()),
    ('rfecv_RFreg', 
     RFECV(estimator = model_RFreg, 
           step = 1, 
           cv = cv_kFold,
           scoring = 'neg_mean_squared_error',  # Using negative MSE as the scoring method
           min_features_to_select = 50,
           n_jobs = -1))
])

# %%
pipe_RFreg.fit(X_train_rf, y_train_trim)

# %%
model_RFreg_fitted = pipe_RFreg.named_steps['rfecv_RFreg'] # Access the fitted rfecv_RF from the pipeline
y_pred_RFreg = pipe_RFreg.predict(X_test_rf)
y_pred_RFreg_train = pipe_RFreg.predict(X_train_rf)

# Performance Metrics of the Training and Test Sets
mse_testRF = mean_squared_error(y_test, y_pred_RFreg) # Mean-Squared Error
R2_testRF = r2_score(y_test, y_pred_RFreg) # R^2
R_testRF = np.corrcoef(y_test, y_pred_RFreg)[0, 1] # Pearson's R: Correlation Coefficient 

mse_testRF = mean_squared_error(y_train_trim, y_pred_RFreg_train) # Mean-Squared Error
R2_testRF = r2_score(y_train_trim, y_pred_RFreg_train) # R^2
R_testRF = np.corrcoef(y_train_trim, y_pred_RFreg_train)[0, 1] # Pearson's R: Correlation Coefficient

# %%
plt.clf()
fig, axs = plt.subplots(1, 2, figsize=(15, 6))

axs[0].scatter(y_train_trim, y_pred_RFreg_train, s=1)
axs[0].plot([y_train_trim.min(), y_train_trim.max()], [y_train_trim.min(), y_train_trim.max()], 'r--') # Best fit line 
axs[0].set_xlabel('Training: Actual N/C Ratio')
axs[0].set_ylabel('Training: Predicted N/C Ratio')
axs[0].set_title(f'Random Forest Regression: A FOVs')
axs[0].text(0.05, 0.95, f'MSE: {mse_trainRF:.3f}, R: {R_trainRF:.3f}, $R^2$: {R2_trainRF:.3f}', 
            transform=axs[0].transAxes,
            verticalalignment='top',
            horizontalalignment='left')

axs[1].scatter(y_test, y_pred_RFreg, s=1)
axs[1].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--') # Best fit line 
axs[1].set_xlabel('Actual N/C Ratio')
axs[1].set_ylabel('Predicted N/C Ratio')
axs[1].set_title(f'Random Forest Regression: {fovs[test_fov]}')
axs[1].text(0.05, 0.95, f'MSE: {mse_testRF:.3f}, R: {R_testRF:.3f}, $R^2$: {R2_testRF:.3f}', 
            transform=axs[1].transAxes,
            verticalalignment='top',
            horizontalalignment='left')

plt.tight_layout()
#plt.savefig(f"./figs/ratioN2C_RF_{fovs[test_fov]}_trajl{trajl}_VAE{latent_dim}.png", dpi=400, bbox_inches='tight')
plt.show()

# %%
################################## KDE + Contour Plot ##################################
plt.clf()
fig, axs = plt.subplots(1, 2, figsize=(15, 6))

xy = np.vstack([y_train_trim, y_pred_RFreg_train])
z = scipy.stats.gaussian_kde(xy)(xy)    
sc = axs[0].scatter(y_train_trim, y_pred_RFreg_train, c=z, s=1, label='Data Points')
axs[0].tricontour(y_train_trim, y_pred_RFreg_train, z, levels=14, linewidths=0.5, colors='k')
contour_plot = axs[0].tricontourf(y_train_trim, y_pred_RFreg_train, z, levels=14, cmap="RdBu_r")
fig.colorbar(contour_plot, ax=axs[0], label='Density')
axs[0].set_xlabel('Training: Actual Ratio')
axs[0].set_ylabel('Training: Predicted Ratio')
axs[0].set_title(f'Random Forest Regressor: A FOVs')

xy = np.vstack([y_test, y_pred_RFreg])
z = scipy.stats.gaussian_kde(xy)(xy)
sc = axs[1].scatter(y_test, y_pred_RFreg, c=z, s=1, label='Data Points')
axs[1].tricontour(y_test, y_pred_RFreg, z, levels=14, linewidths=0.5, colors='k')
contour_plot = axs[1].tricontourf(y_test, y_pred_RFreg, z, levels=14, cmap="RdBu_r")
fig.colorbar(contour_plot, ax=axs[1], label='Density')
axs[1].set_xlabel('Actual Ratio')
axs[1].set_ylabel('Predicted Ratio')
axs[1].set_title(f'Random Forest Regressor: {fovs[test_fov]}')
plt.tight_layout()
#plt.savefig(f"./figs/ratioN2C_RF_{fovs[test_fov]}_trajl{trajl}_VAE{latent_dim}Contours.png", dpi=400, bbox_inches='tight')
plt.show()

# %%
min_features_to_select = 1
n_scores = len(model_RFreg_fitted.cv_results_["mean_test_score"])
plt.clf()
plt.figure(figsize = (5, 4))
plt.xlabel("Number of features selected")
plt.ylabel("Mean test accuracy")
plt.errorbar(range(min_features_to_select, n_scores + min_features_to_select), model_RFreg_fitted.cv_results_["mean_test_score"], 
             yerr=model_RFreg_fitted.cv_results_["std_test_score"])
plt.title("RFE with correlated features")
plt.tight_layout()
#plt.savefig(f'./figs/ratioN2C_RF_{fovs[test_fov]}_trajl{trajl}_VAE{latent_dim}Score.png', dpi = 400, bbox_inches='tight')
plt.show()
